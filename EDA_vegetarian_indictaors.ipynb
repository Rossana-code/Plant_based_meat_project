# %% [markdown]
# <span style="font-size:3em;"> Analysis of the global plant-based meat market </span>

# %% [markdown]
# This is an analysis of the global plant-based meat market, that take into consideration the following three axes for each country: water shortages, the meat consumption in relation to the production and the percentage of vegetarians, creating a coefficient to predict which country will be more suited to the market.
#
# The following notebook is the cleaning and prep of the vegetarian population part.
# This CSV file, along to the other parts of the analysis, has been used to build a dashbord in Tableau, that you can find here:
# https://public.tableau.com/app/profile/rossana.coro/viz/VegetalMeatProject/Accueil

# %%
import pandas as pd
import numpy as np

# %%
#Import csv file from folder
dataset_brut = pd.read_csv("/Users/rossana/Desktop/demoday/fichiers bruts/vegetarianism-by-country-2023.csv")
dataset_brut.head()
# Out:
#    place     pop2023  growthRate      area        country cca3 cca2  ccn3  \
# 0    356  1428627663     0.00808   3287590          India  IND   IN   356
# 1    156  1425671352    -0.00015   9706961          China  CHN   CN   156
# 2    840   339996563     0.00505   9372610  United States  USA   US   840
# 3     76   216422446     0.00515   8515767         Brazil  BRA   BR    76
# 4    643   144444359    -0.00186  17098242         Russia  RUS   RU   643
#
#           region                          subregion  unMember  \
# 0           Asia  Southern Asia, South Central Asia      True
# 1           Asia                       Eastern Asia      True
# 2  North America                   Northern America      True
# 3  South America       South America, Latin America      True
# 4         Europe                     Eastern Europe      True
#
#                     officialName  landAreaKm   density  densityMi  Rank  \
# 0              Republic of India   2973190.0  480.5033  1244.5036     1
# 1     People's Republic of China   9424702.9  151.2696   391.7884     2
# 2       United States of America   9147420.0   37.1686    96.2666     3
# 3  Federative Republic of Brazil   8358140.0   25.8936    67.0645     7
# 4             Russian Federation  16376870.0    8.8200    22.8439     9
#
#    vegetarianismByCountry_percVeg  vegetarianismByCountry_totVeg
# 0                            24.0                      419000000
# 1                             5.0                       50000000
# 2                             5.0                       16000000
# 3                            14.0                       29260000
# 4                             1.0                        1400000

# %%
#Delete unuseful column
dataset = dataset_brut.drop(columns=["place","growthRate","area","cca2","ccn3","unMember","officialName","landAreaKm","density","densityMi"])
dataset.head()
# Out:
#       pop2023        country cca3         region  \
# 0  1428627663          India  IND           Asia
# 1  1425671352          China  CHN           Asia
# 2   339996563  United States  USA  North America
# 3   216422446         Brazil  BRA  South America
# 4   144444359         Russia  RUS         Europe
#
#                            subregion  Rank  vegetarianismByCountry_percVeg  \
# 0  Southern Asia, South Central Asia     1                            24.0
# 1                       Eastern Asia     2                             5.0
# 2                   Northern America     3                             5.0
# 3       South America, Latin America     7                            14.0
# 4                     Eastern Europe     9                             1.0
#
#    vegetarianismByCountry_totVeg
# 0                      419000000
# 1                       50000000
# 2                       16000000
# 3                       29260000
# 4                        1400000

# %%
#Rename columns
dataset = dataset.rename(columns={"pop2023": "Population_2023", "country": "Country",  "cca3": "Location_code", "region": "Continent","subregion": "Sub_continent","vegetarianismByCountry_percVeg": "Vegetarianism_percentage","vegetarianismByCountry_totVeg":"Vegetarian_population"})
dataset.head()
# Out:
#    Population_2023        Country Location_code      Continent  \
# 0       1428627663          India           IND           Asia
# 1       1425671352          China           CHN           Asia
# 2        339996563  United States           USA  North America
# 3        216422446         Brazil           BRA  South America
# 4        144444359         Russia           RUS         Europe
#
#                        Sub_continent  Rank  Vegetarianism_percentage  \
# 0  Southern Asia, South Central Asia     1                      24.0
# 1                       Eastern Asia     2                       5.0
# 2                   Northern America     3                       5.0
# 3       South America, Latin America     7                      14.0
# 4                     Eastern Europe     9                       1.0
#
#    Vegetarian_population
# 0              419000000
# 1               50000000
# 2               16000000
# 3               29260000
# 4                1400000

# %%
#Checking the countries code in order to join them to the main dataset
country_water= dataset['Location_code'].unique()
print(sorted(country_water))
# Out:
# ['ARG', 'BEL', 'BRA', 'CAN', 'CHE', 'CHL', 'CHN', 'CZE', 'DEU', 'DNK', 'ESP', 'EST', 'FIN', 'FRA', 'GRC', 'IND', 'IRL', 'ISR', 'ITA', 'JAM', 'JPN', 'KOR', 'LTU', 'LVA', 'MEX', 'NLD', 'NOR', 'NZL', 'PHL', 'POL', 'PRT', 'RUS', 'SGP', 'SVN', 'SWE', 'THA', 'TWN', 'UKR', 'USA', 'VNM']

# %%
#Keeping just the country that also are in the main dataset in order to join them with the main dataset
country_list = ['AFR', 'ARG', 'ASP', 'AUS', 'BRA', 'BRICS', 'CAN', 'CHE', 'CHL', 'CHN', 'COL', 'DVD', 'DVG', 'EGY', 'ETH', 'EUN', 'EUR', 'GBR', 'IDN', 'IND', 'IRN', 'ISR', 'JPN', 'KAZ', 'KOR', 'LAC', 'MEX', 'MYS', 'NGA', 'NOA', 'NOR', 'NZL', 'OCD', 'OECD', 'PAK', 'PER', 'PHL', 'PRY', 'RUS', 'SAU', 'THA', 'TUR', 'UKR', 'USA', 'VNM', 'WLD', 'ZAF']

dataset = dataset[dataset['Location_code'].isin(country_list)]
dataset.shape
# Out:
# (19, 8)

# %%
#Check if the these countries correspond to the main file countries
location = np.unique(dataset['Location_code'])

sorted_location = np.sort(location)

print(sorted_location)
# Out:
# ['ARG' 'BRA' 'CAN' 'CHE' 'CHL' 'CHN' 'IND' 'ISR' 'JPN' 'KOR' 'MEX' 'NOR'
#  'NZL' 'PHL' 'RUS' 'THA' 'UKR' 'USA' 'VNM']

# %%
#Does the values are consistent?
dataset.describe(include="all")
# Out:
#         Population_2023 Country Location_code Continent Sub_continent  \
# count      1.900000e+01      19            19        19            19
# unique              NaN      19            19         5            11
# top                 NaN   India           IND      Asia  Eastern Asia
# freq                NaN       1             1         8             3
# mean       2.271735e+08     NaN           NaN       NaN           NaN
# std        4.310776e+08     NaN           NaN       NaN           NaN
# min        5.228100e+06     NaN           NaN       NaN           NaN
# 25%        2.818711e+07     NaN           NaN       NaN           NaN
# 50%        7.180128e+07     NaN           NaN       NaN           NaN
# 75%        1.364500e+08     NaN           NaN       NaN           NaN
# max        1.428628e+09     NaN           NaN       NaN           NaN
#
#               Rank  Vegetarianism_percentage  Vegetarian_population
# count    19.000000                 19.000000           1.900000e+01
# unique         NaN                       NaN                    NaN
# top            NaN                       NaN                    NaN
# freq           NaN                       NaN                    NaN
# mean     38.947368                  8.710526           3.039111e+07
# std      41.343377                  5.770316           9.499412e+07
# min       1.000000                  1.000000           4.250000e+05
# 25%       9.500000                  5.000000           1.223000e+06
# 50%      20.000000                  7.000000           2.300000e+06
# 75%      53.000000                 11.000000           1.358000e+07
# max     123.000000                 24.000000           4.190000e+08

# %%
print("Yes, they are")
# Out:
# Yes, they are

# %%
#Export new file csv in order to join it to the main table in the dashboard
dataset.to_csv(r"/Users/rossana/Desktop/demoday/Vegetarianism_per_country.csv")
